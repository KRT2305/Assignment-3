# %% [markdown]
# # Assignment 3 - Logistic Regression
#
# Given the marks of a student in two subjects we want to predict whether he will get admission or not.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from model import *
from utils import *

# %%
file = 'marks.csv'

# %%
X, Y, admitted, not_admitted = load_data(file)

# %% [markdown]
# ### Visualize dataset

# %%
visualize_data(admitted, not_admitted)

# %% [markdown]
# ### Train the model

# %%
# Try changing the learning rate and number of iterations

##################
lr = 0.0015
num_iters = 90000
##################

model = LogisticRegression() 
model.train(X, Y, lr,num_iters,10)
print("Model Accuracy: {}".format(model.accuracy(X,Y)))
# Out:
# Iteration 0 of 90000. Loss: 0.693147 LR: 0.001500
# Iteration 9000 of 90000. Loss: 0.652552 LR: 0.001500
# Iteration 18000 of 90000. Loss: 0.660625 LR: 0.001500
# Iteration 27000 of 90000. Loss: 0.609352 LR: 0.001500
# Iteration 36000 of 90000. Loss: 0.564050 LR: 0.001500
# Iteration 45000 of 90000. Loss: 0.522659 LR: 0.001500
# Iteration 54000 of 90000. Loss: 0.483675 LR: 0.001500
# Iteration 63000 of 90000. Loss: 0.446050 LR: 0.001500
# Iteration 72000 of 90000. Loss: 0.409082 LR: 0.001500
# Iteration 81000 of 90000. Loss: 0.372248 LR: 0.001500
# Model Accuracy: 0.92

# %% [markdown]
# ### Visualize Decision Boundary

# %%
visualize_decision_boundary(admitted, not_admitted, X, model.weights.flatten())

# %% [markdown]
# ### Save hyperparameters

# %%
save_hyperparameters(lr, num_iters)
